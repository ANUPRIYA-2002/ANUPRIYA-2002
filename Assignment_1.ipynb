# %% [markdown]
# # Basic Python

# %% [markdown]
# ## 1. Split this string

# %%
s = "Hi there Sam!"

# %%
t=s.split()
print(s)

# %% [markdown]
# ## 2. Use .format() to print the following string.
#
# ### Output should be: The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742

# %%
txt = "the diameter of {planet} is {diameter} kilometers".format(planet="earth",diameter=12742)
print(txt)

# %% [markdown]
# ## 3. In this nest dictionary grab the word "hello"

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
print(d['k1'][3]['tricky'][3]['target'][3])

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %% [markdown]
# ## 4.1 Create an array of 10 zeros?
# ## 4.2 Create an array of 10 fives?

# %%
import numpy as np
array=np.zeros(10)
print("An array of 10 zeros:")
print(array)

# %%
import numpy as np
array=np.ones(10)*5
print("An array of 10 fives:")
print(array)

# %% [markdown]
# ## 5. Create an array of all the even integers from 20 to 35

# %%
import numpy as np
array=np.arange(20,35,2)
print("An array of all even integer from 20 to 35:")
print(array)

# %% [markdown]
# ## 6. Create a 3x3 matrix with values ranging from 0 to 8

# %%
import numpy as np
array=np.arange(0,9).reshape(3,3)
print("An array of all even integer from 20 to 35:")
print(array)

# %% [markdown]
# ## 7. Concatenate a and b
# ## a = np.array([1, 2, 3]), b = np.array([4, 5, 6])

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.concatenate((a,b))
print(c)

# %% [markdown]
# # Pandas

# %% [markdown]
# ## 8. Create a dataframe with 3 rows and 2 columns

# %%
import pandas as pd

# %%
import pandas as pd
data = [['Let us c',400,546],['Learn python',500,456]]
df = pd.DataFrame(data, columns={'Book Name','Book Price','Total_Pages'})
print(df)

# %% [markdown]
# ## 9. Generate the series of dates from 1st Jan, 2023 to 10th Feb, 2023

# %%
import datetime
import pandas as pd
start = datetime.datetime.strptime("01-01-2023", "%d-%m-%Y")
end = datetime.datetime.strptime("10-02-2023", "%d-%m-%Y")
date_generated = pd.date_range(start, end)
print date_generated.strftime("%d-%m-%Y")

# %% [markdown]
# ## 10. Create 2D list to DataFrame
#
# lists = [[1, 'aaa', 22],
#          [2, 'bbb', 25],
#          [3, 'ccc', 24]]

# %%
lists = [[1, 'aaa', 22], [2, 'bbb', 25], [3, 'ccc', 24]]

# %%
import pandas as pd
lists = [[1,'aaa',22],[2,'bbb',25],[3,'ccc',24]]
df = pd.DataFrame(lists)
print(df)
